# %%
import hdob

from datetime import datetime

# %%
t1 = datetime(2017, 9, 1)
t2 = datetime(2017, 9, 10)
hdobs = hdob.available_hdobs_between(t1, t2, storm='IRMA')

# %%
first = next(hdobs)

# %%
first.header
# Out:
# HDOBHeader(aircraft='AF309', storm='IRMA', ob_seq=3, start_date=datetime.datetime(2017, 9, 4, 0, 0))

# %%
first.data
# Out:
#                   time        lat        lon  pressure  height  \
# 0  2017-09-04 14:15:00  17.700000 -64.616667     833.8    1695
# 1  2017-09-04 14:15:30  17.700000 -64.583333     810.5    1947
# 2  2017-09-04 14:16:00  17.683333 -64.550000     788.5    2181
# 3  2017-09-04 14:16:30  17.683333 -64.516667     763.2    2454
# 4  2017-09-04 14:17:00  17.683333 -64.483333     740.9    2709
# 5  2017-09-04 14:17:30  17.666667 -64.450000     726.2    2878
# 6  2017-09-04 14:18:00  17.666667 -64.416667     713.8    3021
# 7  2017-09-04 14:18:30  17.666667 -64.383333     694.9    3239
# 8  2017-09-04 14:19:00  17.650000 -64.350000     669.9    3547
# 9  2017-09-04 14:19:30  17.650000 -64.333333     652.0    3773
# 10 2017-09-04 14:20:00  17.633333 -64.300000     638.1    3950
# 11 2017-09-04 14:20:30  17.633333 -64.266667     625.3    4116
# 12 2017-09-04 14:21:00  17.633333 -64.233333     612.3    4287
# 13 2017-09-04 14:21:30  17.616667 -64.200000     599.2    4462
# 14 2017-09-04 14:22:00  17.616667 -64.166667     586.9    4631
# 15 2017-09-04 14:22:30  17.600000 -64.133333     574.5    4802
# 16 2017-09-04 14:23:00  17.600000 -64.100000     563.0    4965
# 17 2017-09-04 14:23:30  17.583333 -64.066667     552.9    5110
# 18 2017-09-04 14:24:00  17.583333 -64.033333     543.0    5256
# 19 2017-09-04 14:24:30  17.583333 -64.000000     534.8    5376
#
#     xtrp_sfc_pressure  temp  dewpt       wind  peak_fl_wind sfmr_wind  \
# 0              1013.7  16.4   12.0   (10, 93)            11
# 1              1014.5  15.4   10.1   (10, 87)            10
# 2              1014.0  14.6    8.7   (10, 84)            10
# 3              1013.5  13.5    5.4   (11, 83)            11
# 4              1013.1  12.8    3.4   (12, 78)            13
# 5              1013.2  11.9    1.8   (12, 85)            12
# 6              1013.0  11.2   -2.5  (12, 100)            12
# 7              1012.2  10.2   -5.1  (12, 103)            13
# 8              1013.0   7.8   -1.4  (11, 107)            12
# 9              1013.7   6.3   -3.1  (10, 111)            11
# 10             1013.4   5.4   -6.5    (7, 98)             9
# 11             1013.2   4.7  -10.5    (6, 73)             7
# 12             1013.3   3.5  -11.1    (3, 81)             5
# 13             1012.4   3.1  -15.4   (5, 117)             5
# 14             1012.3   2.1  -16.0   (6, 110)             7
# 15             1011.5   1.4  -22.2   (10, 83)            11
# 16             1011.8   0.3  -24.6   (10, 85)            11
# 17             1011.4  -0.4  -24.5   (10, 91)            11
# 18             1029.6  -1.2  -26.9   (10, 80)            11
# 19             1030.4  -1.7  -29.4    (8, 77)             9
#
#    sfmr_rain_rates  qc
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3
# 5                    3
# 6                    3
# 7                    3
# 8                    3
# 9                    3
# 10                   3
# 11                   3
# 12                   3
# 13                   3
# 14                   3
# 15                   3
# 16                   3
# 17                   3
# 18                   3
# 19                   3

# %%
hdob.columns
# Out:
# HDOBColumns(time='time', lat='lat', lon='lon', pressure='pressure', height='height', xtrp_sfc_pressure='xtrp_sfc_pressure', temp='temp', dewpt='dewpt', wind='wind', peak_fl_wind='peak_fl_wind', sfmr_wind='sfmr_wind', sfmr_rain_rates='sfmr_rain_rates', qc='qc')
